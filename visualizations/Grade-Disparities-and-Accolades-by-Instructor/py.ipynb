# %%
import pandas as pd

# %%
df = pd.read_csv("final.csv")
df
# Out:
#          instructor                                         course  \
# 0              Kang          AAS 100: Intro Asian American Studies
# 1          Espiritu          AAS 100: Intro Asian American Studies
# 2               Lee          AAS 100: Intro Asian American Studies
# 3             Zheng          AAS 100: Intro Asian American Studies
# 4     Rosado-Torres          AAS 100: Intro Asian American Studies
# ...             ...                                            ...
# 7427       Aldridge    VM 652: Large Animal Medicine and Surgery I
# 7428        Ridgway   VM 653: Small Animal Medicine and Surgery II
# 7429       Aldridge   VM 654: Large Animal Medicine and Surgery II
# 7430        Ridgway  VM 655: Small Animal Medicine and Surgery III
# 7431        Garrett  VM 656: Large Animal Medicine and Surgery III
#
#                                 course_name  num_excellence_awards  \
# 0              Intro Asian American Studies                    0.0
# ...

# %%
df.columns
# Out:
# Index(['instructor', 'course', 'course_name', 'num_excellence_awards',
#        'num_outstanding_awards', 'uiuc_award', 'national_award',
#        'rmp_num_reviews', 'rmp_rating', 'A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+',
#        'C', 'C-', 'D+', 'D', 'D-', 'F', 'num_sections', 'gened',
#        'num_semesters', 'num_students', 'avg_gpa', 'total_faculty_awards',
#        'teaching_next_semester'],
#       dtype='object')

# %%
df[ df["national_award"] != "[]"]
# Out:
#      instructor                                          course  \
# 1564      Moore            CHEM 332: Elementary Organic Chem II
# 1572    Denmark                 CHEM 437: Organic Chemistry Lab
# 1574   Gruebele         CHEM 440: Physical Chemistry Principles
# 1577   Gruebele                  CHEM 442: Physical Chemistry I
# 1587    Denmark            CHEM 530: Structure and Spectroscopy
# 2590      Hajek         ECE 314: Probability in Engineering Lab
# 2723      Hajek         ECE 515: Control System Theory & Design
# 4281  Berenbaum  IB 435: Critical Evaluation of Herbal Remedies
#
#                                  course_name  num_excellence_awards  \
# 1564              Elementary Organic Chem II                    1.0
# 1572                   Organic Chemistry Lab                    4.0
# 1574           Physical Chemistry Principles                    4.0
# 1577                    Physical Chemistry I                    4.0
# ...

# %%
df["national_award"].unique()
# Out:
# array(['[]', "['National Academy of Sciences']",
#        "['National Academy of Engineering']"], dtype=object)
